# %% [markdown]
# ### 네이버 쇼핑 키워드 인사이트
#
# #### 개인과제
# - 키워드에 대한 검색량 데이터 수집
# - 검색어에 대한 상품등록수 수집
# - 수집한 데이터에 대한 인사이트 도출 : 예시) 경쟁률
#
# #### 조별과제
# - 스마트 스토어를 운영한다고 생각하고 경쟁력이 낮으면서 많은 수익을 낼수 있는 키워드와 상품 찾기
#     - 예시외의 추가적인 페이지 데이터 수집하여 프로젝트 수행가능

# %% [markdown]
# #### 참고 서비스
# - 신사임당 유투브 : https://youtu.be/Z0hL9khbpIw
# - 응용 서비스 : https://whereispost.com/keyword, https://itemscout.io

# %% [markdown]
# #### 데이터 수집 프로세스
# 1. 네이버 검색광고 회원가입 및 로그인 : https://searchad.naver.com
# 2. 광고 시스템 > 도구 > API 사용관리
# 3. CUSTOMER_ID, API_KEY, SECRET_KEY 획득
# 4. 네이버 검색 광고 API 매뉴얼 사이트 참고 : http://naver.github.io/searchad-apidoc/#/guides
# 5. github 페이지 참고
#     - https://github.com/naver/searchad-apidoc
#     - https://github.com/naver/searchad-apidoc/blob/master/python-sample/examples/ad_management_sample.py
# 6. 키워드 입력하면 해당 키워드에 대한 데이터 수집

# %% [markdown]
# - hint
#     - github 페이지의 코드에서 signaturehelper.py 파일을 이용하여 header를 만들어야 합니다.

# %%
import requests, json, time
import pandas as pd
import signaturehelper
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### 1. 개별과제 : 키워드에 대한 검색량 데이터 수집

# %%
def keyword_master(keyword):
    pass

# %%
keyword = "실내자전거"
df = keyword_master(keyword)

# %%
df.head()
# Out:
#   relKeyword monthlyPcQcCnt monthlyMobileQcCnt  monthlyAvePcClkCnt  \
# 0      실내자전거          18300             159100               117.7
# 1      온라인PT            580               1600                14.5
# 2     하체운동기구           1070               7800                 6.3
# 3     스피닝자전거           2380              25000                13.9
# 4      헬스자전거           1270              11500                17.8
#
#    monthlyAveMobileClkCnt  monthlyAvePcCtr  monthlyAveMobileCtr  plAvgDepth  \
# 0                  2666.3             0.72                 1.81          15
# 1                   105.4             2.70                 6.68          15
# 2                   119.9             0.67                 1.65          15
# 3                   369.1             0.63                 1.57          15
# 4                   322.3             1.54                 3.06          15
#
#   compIdx
# 0      높음
# 1      높음
# 2      높음
# 3      높음
# 4      높음

# %%
def get_header(method, uri, api_key, secret_key, customer_id):
    timestamp = str(round(time.time() * 1000))
    signature = signaturehelper.Signature.generate(timestamp, method, uri, SECRET_KEY)
    return {'Content-Type': 'application/json; charset=UTF-8', 'X-Timestamp': timestamp, 'X-API-KEY': API_KEY, 'X-Customer': str(CUSTOMER_ID), 'X-Signature': signature}


BASE_URL = 'https://api.naver.com'
API_KEY = '0100000000f659663a32ddcf2524608ca10d7f1f874f03f29318d2c5c8b891860602e7c555'
SECRET_KEY = 'AQAAAAD2WWY6Mt3PJSRgjKENfx+Hnj/2V/o/mVw3yzpALQMYaQ=='
CUSTOMER_ID = '2488388'

# %%
def keyword_master(keyword):
    uri = '/keywordstool'
    method = 'GET'
    r = requests.get(BASE_URL + uri+f'?hintKeywords={keyword}&showDetail=1',
                 headers=get_header(method, uri, API_KEY, SECRET_KEY, CUSTOMER_ID))
    return pd.DataFrame(r.json()['keywordList'])

# %%
keyword = "스틱커피"
df1 = keyword_master(keyword)

# %%
df1.head(40)
# Out:
#   relKeyword monthlyPcQcCnt monthlyMobileQcCnt  monthlyAvePcClkCnt  \
# 0       스틱커피            700               2460                 2.3
# 1      천연카페인             60                200                 0.6
# 2     헤이즐넛커피            980               9220                 2.9
# 3         바륨            790               3070                 1.2
# 4       회사간식           1430               3000                26.7
#
#    monthlyAveMobileClkCnt  monthlyAvePcCtr  monthlyAveMobileCtr  plAvgDepth  \
# 0                    20.3             0.35                 0.89          15
# 1                     2.3             1.15                 1.32          13
# 2                   100.3             0.32                 1.19          15
# 3                     2.0             0.17                 0.07           9
# 4                    54.5             2.16                 2.13          15
#
#   compIdx
# 0      높음
# 1      중간
# 2      높음
# 3      중간
# 4      높음

# %%
df1
# Out:
#      relKeyword monthlyPcQcCnt monthlyMobileQcCnt  monthlyAvePcClkCnt  \
# 0          스틱커피            700               2460                 2.3
# 1         천연카페인             60                200                 0.6
# 2        헤이즐넛커피            980               9220                 2.9
# 3            바륨            790               3070                 1.2
# 4          회사간식           1430               3000                26.7
# ..          ...            ...                ...                 ...
# 439  맥심화이트골드160            110                450                 0.1
# 440        더치기계             20                120                 0.2
# 441        마이더치            180               1010                 0.3
# 442      더치커피기계             60                240                 0.8
# 443     더치커피추출기             10                 60                 0.3
#
#      monthlyAveMobileClkCnt  monthlyAvePcCtr  monthlyAveMobileCtr  plAvgDepth  \
# 0                      20.3             0.35                 0.89          15
# 1                       2.3             1.15                 1.32          13
# 2                     100.3             0.32                 1.19          15
# 3                       2.0             0.17                 0.07           9
# 4                      54.5             2.16                 2.13          15
# ..                      ...              ...                  ...         ...
# 439                     2.3             0.14                 0.57          15
# 440                     0.0             0.91                 0.00          15
# 441                     7.0             0.16                 0.73          14
# 442                     6.3             1.27                 3.17          15
# 443                     0.0             1.76                 0.00          15
#
#     compIdx
# 0        높음
# 1        중간
# 2        높음
# 3        중간
# 4        높음
# ..      ...
# 439      높음
# 440      높음
# 441      높음
# 442      높음
# 443      높음
#
# [444 rows x 9 columns]

# %% [markdown]
# #### 2. 개별과제 : 검색어에 대한 상품등록수 수집
# - item_count : 등록된 상품수
# - total_search_count : PC, Mobile 을 합친 검색량

# %%
def item_count(keyword):
    pass

# %%
result_df
# Out:
#    relKeyword  monthlyPcQcCnt  monthlyMobileQcCnt  item_count  \
# 0       실내자전거           18300              159100      245638
# 1       온라인PT             580                1600       11983
# 2      하체운동기구            1070                7800       56684
# 3      스피닝자전거            2380               25000       60342
# 4       헬스자전거            1270               11500      243545
# 5          홈트            4500               19900      924110
# 6       스쿼트머신            2230               17100       45269
# 7      다리운동기구             360                4110       73169
# 8      실내운동기구            1530               13300      341120
# 9       실내사이클            3600               32500      140261
# 10       딥다라인             370                3550          50
# 11      실내싸이클            1290               11900      140261
# 12        라이딩             940                5720     1214412
# 13      스핀바이크            2240               10400       22938
# 14      홈트레이닝            3790                5660      612252
# 15       운동기구            4340               23600     2013909
# 16    실내자전거렌탈             100                 790         581
# 17      밸런스보드            5710               30200      105822
# 18    자전거운동기구             570                5550      158543
# 19    가정용운동기구             420                2970      367701
#
#     total_search_count
# 0               177400
# 1                 2180
# 2                 8870
# 3                27380
# 4                12770
# 5                24400
# 6                19330
# 7                 4470
# 8                14830
# 9                36100
# 10                3920
# 11               13190
# 12                6660
# 13               12640
# 14                9450
# 15               27940
# 16                 890
# 17               35910
# 18                6120
# 19                3390

# %%
from scrapy.http import TextResponse

# %%
keywords = []
keywords = df1['relKeyword']

# %%
#//*[@id="__next"]/div/div[2]/div[2]/div[4]/div[1]/div[1]/ul/li[1]/a/span[1]
# //*[@id="__next"]/div/div[2]/div/div[3]/div[1]/div[1]/ul/li[1]/a/span[1]
# //*[@id="__next"]/div/div[2]/div[2]/div[3]/div[1]/div[1]/ul/li[1]/a/span[1]




def item_count(keyword):
    total_count = []
    url = f'https://search.shopping.naver.com/search/all?query={keyword}'
    req = requests.get(url)
    response = TextResponse(req.url, body=req.text, encoding='utf-8')
    try:
        return int(response.xpath('//*[@id="__next"]/div/div[2]/div[2]/div[3]/div[1]/div[1]/ul/li[1]/a/span[1]/text()')[0].extract().replace(',', ''))
    except:
        return int(response.xpath('//*[@id="__next"]/div/div[2]/div/div[3]/div[1]/div[1]/ul/li[1]/a/span[1]/text()')[0].extract().replace(',', ''))

# %%
keywords[:50]
# Out:
# 0             스틱커피
# 1            천연카페인
# 2           헤이즐넛커피
# 3               바륨
# 4             회사간식
# 5          캐모마일차효능
# 6             시트르산
# 7     L-카르니틴타르트레이트
# 8             버터커피
# 9             방탄커피
# 10           사무실간식
# 11          맥심커피믹스
# 12            더치커피
# 13            액상커피
# 14          디카페인커피
# 15             알커피
# 16           홈카페용품
# 17         에스프레소원액
# 18        키토제닉다이어트
# 19             음료수
# 20            음료도매
# 21          디카페인원두
# 22           항산화커피
# 23         카누아메리카노
# 24           커피박람회
# 25           베트남커피
# 26            콜드브루
# 27            커피티백
# 28           피로회복제
# 29           드립백커피
# 30              맥심
# 31           탕비실간식
# 32          캔음료수도매
# 33            커피메뉴
# 34          맥심모카골드
# 35          믹스커피추천
# 36        저탄고지다이어트
# 37          공정무역커피
# 38            당뇨커피
# 39       커피프렌차이즈순위
# 40        디카페인커피믹스
# 41            쟈뎅커피
# 42            커피맛집
# 43            맥심커피
# 44           캐모마일차
# 45             캔음료
# 46          콜드브루원액
# 47           에너지충전
# 48            드립커피
# 49          캐모마일효능
# Name: relKeyword, dtype: object

# %%
total_count2 = []
for keyword in keywords:
    try:
        total_count2.append(item_count(keyword))
        print(keyword)
    except:
        total_count2.append(0)
        print(keyword+'1')
# Out:
# 스틱커피
# 천연카페인
# 헤이즐넛커피
# 바륨
# 회사간식
# 캐모마일차효능
# 시트르산
# L-카르니틴타르트레이트
# 버터커피
# 방탄커피
# 사무실간식
# 맥심커피믹스
# 더치커피
# 액상커피
# 디카페인커피
# 알커피
# 홈카페용품
# 에스프레소원액
# 키토제닉다이어트
# 음료수
# 음료도매
# 디카페인원두
# 항산화커피
# 카누아메리카노
# 커피박람회
# 베트남커피
# 콜드브루
# 커피티백
# 피로회복제
# 드립백커피
# 맥심
# 탕비실간식
# 캔음료수도매
# 커피메뉴
# 맥심모카골드
# 믹스커피추천
# 저탄고지다이어트
# 공정무역커피
# 당뇨커피
# 커피프렌차이즈순위
# 디카페인커피믹스
# 쟈뎅커피
# 커피맛집
# 맥심커피
# 캐모마일차
# 캔음료
# 콜드브루원액
# 에너지충전
# 드립커피
# 캐모마일효능
# 액상스틱커피
# 카누
# 과자도매
# 과자
# 사무실음료
# 업소용음료
# 커피종류
# 음료수도매
# 더치커피원액
# 아메리카노원액
# 과자몰
# 카모마일차
# 캐모마일티백
# 남성피로회복제
# L카르니틴
# 루카스나인라떼
# 카모마일효능
# 커피원액
# 맛있는믹스커피추천
# 아이스큐브라떼
# BULLETPROOFCOFFEE1
# 에스프레소액상
# 케톤다이어트
# 콜드부르
# 콜드블루만들기
# 콜드블루액상
# 더치커피만드는법
# 아메리카노콜드브루
# 업소용콜드브루
# 일회용더치커피
# 다니엘커피
# 더치커피기구제작
# 코드브루
# 아메리카노액상
# 커피백
# 커피선물세트
# 루왁커피
# 드립백포장박스
# 드립백커피추천
# 고급커피
# 커피세트
# 커피용품
# 커피패키지
# 커피필터
# 티백커피
# 핸드드립커피
# 핸드드립커피세트
# 헤즐넛커피
# 홈커피머신
# 커피드리퍼세트
# 커피드립백
# 아메리카노
# 맥심커피믹스400
# 콜드프레소
# 베트남연유커피
# 일회용커피
# 아이스콜드브루
# 커피스틱
# 페르네
# 프렌치카페
# 프렌치카페믹스
# 핫쵸코
# 헤즐럿커피
# 복음자리유자차
# 블루베리아이스티
# 아라비카100
# 아이스커피믹스
# 아이스티복숭아
# 오뚜기생강차
# 자판기믹스
# 카누100
# 카누아이스
# 네스카페믹스
# 네스카페커피
# 단호박마차
# 담터단호박마차
# 도라지생강차
# 루카스나인바닐라라떼
# 린저21
# 맥스웰마일드
# 맥심모카믹스
# 맥심믹스
# 맥심아이스커피믹스
# 모카아라비카
# 루카스나인
# 루카스나인더블샷라떼
# 루카스9
# 프렌치카페커피믹스
# 콜드브루파우치
# 맛있는더치커피
# 빼자커피
# LOOKAS9
# 커피대통령
# 더치커피맛집
# 커피액상
# 더치큐브
# 콜드브루가격
# 크리머
# 목초버터
# BULLETPROOF
# 액상에스프레소
# 집에서아메리카노
# 아메리카노만들기
# 귀리식이섬유
# 간헐적단식효과
# 맥심모카
# 콜드브루추천
# 한차
# 대호아이스티
# 결혼식답례품커피
# 자판기율무차
# 콜드브루대용량
# 대용량아메리카노
# 핫초코
# 대용량더치커피
# 복숭아아이스티
# 옥수수수염차티백
# 콜드블루
# 네슬레핫초코
# 커피파우치
# 더치원액
# 동서옥수수차
# 더치커피파우치
# 콜드브루더치커피
# COLDBREW
# 레몬아이스티
# 돌체라떼
# 안산더치커피
# 핫초코미떼
# 커피믹스도매
# 남성잠옷바지
# 발효커피
# 보리커피
# 커피가루
# 결명차
# 방탄커피버터
# 자판기원두
# 방탄커피먹는방법
# 맥심도매
# 커피재료도매
# 콜드브루만들기
# 더치커피추천
# 홈카페커피
# 콜드브루커피
# 방탄커피효능
# 더치커피스틱
# 파우치더치커피
# 라떼
# 방탄커피다이어트
# 도매커피
# 탐라커피
# 위드오커피
# 동서메밀차
# 방탄버터커피
# 케토다이어트
# 더치커피브랜드
# 콜드블루커피
# 지세븐커피
# 카페쓰어다
# 연유라떼만들기
# 더치콜드브루
# 더치커피유통기한
# 콜드브루500ML
# 빅트레인토피모카
# 라떼베이스
# 바른선달밤라떼1
# 방탄커피효과
# 콜드브루판매
# 방탄커피레시피
# 방탄커피MCT오일
# 커피도매사이트
# 고기다이어트
# 콜드브루선물
# 업소용더치커피
# 키토제닉커피
# 커피오일
# MCT오일방탄커피
# 방탄커피코코넛오일
# 방탄커피재료
# 콜드브루기계
# 커피믹스
# 콜드부르커피
# 콜드브루선물세트
# 콜드브루답례품
# 커피믹스자판기
# 방탄커피만들기
# 바리스타원두
# 가정용더치커피
# 9HOURS
# 나인아워즈
# 결혼답례품더치커피
# DUTCHCOFFEE
# 코스트코방탄커피
# 옥수수수염차
# 유기농결명자
# 국산결명자차
# 자색옥수수차
# 부산양도양수1
# 간헐적단식
# 핸드메이드커피
# 고급더치커피
# 요거트믹스
# 호지티믹스
# 옥수수수염
# 더치커피전문점
# 더치커피500ML
# 콜드브루1L
# 콜드블루원액
# 복숭아홍차
# 복숭아차
# 콜드브루포장
# 롯데옥수수수염차
# 옥수수수염차500
# 아치카페
# 더치커피가격
# 에디오피아
# 커피대량구매
# 더치커피판매
# 프리미엄더치커피
# 홈카페재료
# 과테말라디카페인
# 맥스웰커피믹스
# 더치커피도매
# 커피유통
# 더치커피제조
# 콜드브루납품
# 비건핫초코
# 선물용더치커피
# 콜드브루전문점
# L-카르니틴다이어트
# 더블샷라떼
# 커피카누
# 맥심모카골드100T
# 맥심1/2
# 맥심모카골드믹스
# 맥심모카골드커피믹스
# 맥심아라비카
# 부드러운블랙
# 카누스위트
# 카누150T
# 카누100T
# 맥심모카골드230
# 나이트로콜드브루
# 디카페인라떼
# 더치커피보틀
# 더치커피예가체프
# 에콰도르원두
# 볶은결명자
# 더치커피납품
# 카누라떼
# 카누미니150
# 설탕없는커피믹스
# 무설탕커피
# 무설탕커피믹스
# 설탕없는믹스커피
# 저칼로리커피믹스
# 프리미엄믹스커피
# 커피믹스추천
# 카누150
# 에스프레스커피
# 맥심카누
# 카누디카페인
# 동서커피믹스
# 더치커피선물세트
# 카누다크로스트
# 무설탕믹스커피
# 라떼커피
# 카누마일드로스트미니
# 더치커피선물
# 카누다크로스트미니
# 코코넛커피
# 연아커피
# 화이트믹스
# 디카페인카누
# 맥심400
# 화이트커피믹스
# 카누마일드로스트
# 카누마일드미니
# 카누미니마일드150
# 카누아이스아메리카노
# 카누커피
# 커피모카골드
# 커피믹스400
# 커피믹스대용량
# 맥심디카페인
# 맥심라이트
# 맥심모카골드400T
# 맥심모카골드화이트
# 맥심믹스커피
# 맥심블랙
# 맥심선물세트
# 맥심오리지날500G
# 맥심오리지날리필
# 맥심커피400
# 맥심커피가격
# 맥심커피리필
# 맥심커피믹스160T
# 맥심커피믹스400T
# 맥심커피믹스모카골드
# 맥심커피블랙
# 맥심화이트골드200
# 모카골드커피믹스
# KANU
# 골드믹스
# 공유커피
# 김연아커피
# 동서믹스커피
# 베트남족제비커피
# 콜드브루OEM
# 자판기업체
# 믹스커피자판기
# 간헐적단식커피
# 카누디카페인미니
# 코스트코스타벅스원두
# 카라멜마끼아또
# 카페라떼캡슐
# 맥스웰커피
# 콜드브루메이커
# 콜드브루선물용
# 콜드브루공장
# 원주더치커피
# 베트남연유
# 스타벅스더치커피
# 아메리카노다이어트
# 매실차
# 더치선물세트
# 아이스아메리카노
# 더치커피유리병
# 예가체프더치커피
# 카카오가루
# 초콜릿파우더
# 사이폰커피
# 007마켓
# 더치커피OEM
# 파지아노
# COFFEE
# 더치커피세트
# 맥심모카골드160
# 답례품커피
# 맥심모카골드400
# 아이스커피
# 호두율무차
# 맥심화이트
# L카르니틴타르트레이트
# 더치커피원액선물
# 맥심모카골드320
# 프릿츠
# 여직원선물
# 에스프레소
# 더치커피답례품
# 남자체지방률
# 아이스초코
# 맥심모카골드사은품
# 더치커피공장
# 카누다크
# 탕비실커피
# 디카페인더치
# 근적외선벨트
# 카누마일드
# 추석커피선물세트
# 더치커피포장
# 답례품더치커피
# 레몬파우더
# 홈카페꾸미기
# 맥심화이트골드320
# 맥심화이트골드100
# 결혼답례품커피
# 커피대용차
# 맥심400T
# 문블렌딩
# 케토
# 옥수수수염효능
# 홈카페레시피
# 커피숍음료
# 케톤식이요법
# 선물용커피
# 카페유통
# 수제커피
# 디카페인커피티백
# 모카골드400
# 맥심커피믹스100T
# 단호박차
# 카르니틴다이어트
# 베트남로부스타
# 디카페인콜드브루
# 다이어트커피
# 초코파우더
# 맥심원두커피
# 커피답례품
# 맥심화이트골드160
# 더치기계
# 마이더치
# 더치커피기계
# 더치커피추출기

# %%
total_count2
# Out:
# [147442,
#  925,
#  69232,
#  1361,
#  60329,
#  634,
#  1179,
#  912,
#  13146,
#  8408,
#  160950,
#  188346,
#  106894,
#  34345,
#  80794,
#  67477,
#  755960,
#  3287,
#  1453,
#  471648,
#  79129,
#  34274,
#  948,
#  34192,
#  179,
#  33176,
#  103058,
#  77224,
#  18054,
#  73059,
#  229173,
#  23771,
#  9349,
#  14081,
#  57485,
#  645160,
#  2404,
#  3696,
#  481,
#  629,
#  26226,
#  31024,
#  3162,
#  212168,
#  75345,
#  420186,
#  17786,
#  36577,
#  983569,
#  673,
#  2531,
#  240422,
#  17518,
#  5416472,
#  106698,
#  219793,
#  9894514,
#  33082,
#  20966,
#  1081,
#  125609,
#  75345,
#  45465,
#  3961,
#  23865,
#  15933,
#  673,
#  27613,
#  16953,
#  242,
#  0,
#  7234,
#  1598,
#  494,
#  12411,
#  17421,
#  37,
#  4010,
#  899,
#  803,
#  1384,
#  8963,
#  64,
#  6714,
#  203235,
#  145536,
#  4937,
#  273,
#  73060,
#  144222,
#  1107010,
#  4847710,
#  16991,
#  424768,
#  77224,
#  395101,
#  105890,
#  7492,
#  6445,
#  45413,
#  73060,
#  240583,
#  2244,
#  118,
#  2045,
#  154555,
#  13117,
#  147456,
#  455,
#  21547,
#  14546,
#  69387,
#  70015,
#  2434,
#  1306,
#  22665,
#  12109,
#  41003,
#  4183,
#  16368,
#  22981,
#  2172,
#  36729,
#  64270,
#  5552,
#  5040,
#  12975,
#  3012,
#  371,
#  9895,
#  65413,
#  188609,
#  3731,
#  4412,
#  21806,
#  3996,
#  1870,
#  14455,
#  2486,
#  106901,
#  387,
#  21806,
#  370,
#  43,
#  34302,
#  111,
#  103065,
#  66359,
#  694,
#  7321,
#  7234,
#  2567,
#  3410,
#  5590,
#  12,
#  67320,
#  103065,
#  17917,
#  994,
#  507,
#  3584,
#  1038,
#  4365,
#  69388,
#  956,
#  41004,
#  14615,
#  12411,
#  3667,
#  44309,
#  21629,
#  6828,
#  4581,
#  40173,
#  103064,
#  24789,
#  10613,
#  106900,
#  9913,
#  645235,
#  309765,
#  6854,
#  34483,
#  47025,
#  337,
#  1088,
#  5777,
#  8407,
#  2093,
#  137,
#  3127,
#  106901,
#  304336,
#  86589,
#  28,
#  1214,
#  4581,
#  692057,
#  1271,
#  35052,
#  548,
#  122,
#  4530,
#  1340,
#  17389,
#  106900,
#  2036,
#  26897,
#  980,
#  19164,
#  43290,
#  106900,
#  12067,
#  650,
#  4499,
#  0,
#  1276,
#  103061,
#  29,
#  2674,
#  36284,
#  5426,
#  7522,
#  936,
#  458,
#  34029,
#  35742,
#  598,
#  79,
#  3228,
#  645095,
#  86856,
#  5869,
#  596,
#  15965,
#  105,
#  15954,
#  6269,
#  1144,
#  1144,
#  97,
#  106900,
#  246,
#  59334,
#  582,
#  3457,
#  5075,
#  0,
#  1410,
#  22687,
#  2242,
#  5434,
#  1097,
#  65824,
#  106900,
#  16617,
#  4550,
#  275,
#  26365,
#  20582,
#  1901,
#  4759,
#  10348,
#  3294,
#  106900,
#  5592,
#  6561,
#  106900,
#  2762,
#  4424,
#  1819,
#  30321,
#  3510,
#  14713,
#  13641,
#  17804,
#  330,
#  1935,
#  58,
#  17768,
#  15725,
#  97344,
#  11755,
#  875,
#  55950,
#  55901,
#  14224,
#  231406,
#  11460,
#  6664,
#  18411,
#  180,
#  1566,
#  6563,
#  2576,
#  5587,
#  118,
#  3085,
#  46,
#  40259,
#  8504,
#  486,
#  8963,
#  4795,
#  486,
#  75,
#  703033,
#  645083,
#  9460,
#  619,
#  58202,
#  10898,
#  127764,
#  10761,
#  12563,
#  4795,
#  355703,
#  7356,
#  15082,
#  7739,
#  14995,
#  668,
#  67360,
#  10898,
#  3412,
#  31632,
#  12951,
#  15098,
#  4539,
#  799,
#  97328,
#  66799,
#  5516,
#  12150,
#  9230,
#  5636,
#  926,
#  5357,
#  188447,
#  23047,
#  1996,
#  4577,
#  3569,
#  2282,
#  212150,
#  10490,
#  410,
#  1713,
#  55893,
#  22260,
#  1112,
#  64248,
#  240429,
#  157293,
#  9290,
#  243,
#  127734,
#  475,
#  393,
#  165,
#  15961,
#  154,
#  5301,
#  1721,
#  9266,
#  767,
#  40518,
#  17854,
#  1038,
#  62,
#  39,
#  2418,
#  287,
#  3143,
#  11499,
#  11411,
#  20979,
#  2918,
#  5588,
#  3568,
#  52563,
#  17027,
#  3434,
#  106886,
#  39,
#  9894368,
#  23108,
#  424,
#  11823,
#  1242,
#  141243,
#  42556,
#  26914,
#  912,
#  2578,
#  271,
#  398,
#  517,
#  713719,
#  1729,
#  73,
#  4735,
#  145,
#  55,
#  23533,
#  31145,
#  4853,
#  391,
#  24454,
#  146155,
#  4599,
#  1729,
#  13803,
#  23001,
#  230,
#  5103,
#  527,
#  4755,
#  1718,
#  251,
#  52818,
#  129,
#  887,
#  4730,
#  58,
#  33505,
#  9948,
#  72170,
#  3251,
#  1528,
#  40477,
#  14951,
#  20792,
#  3203,
#  3242,
#  19582,
#  26868,
#  12894,
#  11823,
#  342,
#  3232,
#  1295,
#  2467,
#  18255]

# %%
columns = [ 'monthlyAvePcClkCnt', 'monthlyAveMobileClkCnt', 'monthlyAvePcCtr',
       'monthlyAveMobileCtr', 'plAvgDepth', 'compIdx']

# %%
result_df = df1.drop(columns, axis=1)
result_df.insert(3, 'item_count',total_count2)
result_df['monthlyPcQcCnt'] = result_df['monthlyPcQcCnt'].replace('< ', '', regex=True)
result_df['monthlyMobileQcCnt'] = result_df['monthlyMobileQcCnt'].replace('< ', '', regex=True)
result_df['monthlyPcQcCnt']=result_df['monthlyPcQcCnt'].astype(int)
result_df['monthlyMobileQcCnt'] =result_df['monthlyMobileQcCnt'].astype(int)
result_df['total_search_count'] = (result_df['monthlyPcQcCnt']+result_df['monthlyMobileQcCnt']).astype(int)
result_df
# Out:
#      relKeyword  monthlyPcQcCnt  monthlyMobileQcCnt  item_count  \
# 0          스틱커피             700                2460      147442
# 1         천연카페인              60                 200         925
# 2        헤이즐넛커피             980                9220       69232
# 3            바륨             790                3070        1361
# 4          회사간식            1430                3000       60329
# ..          ...             ...                 ...         ...
# 439  맥심화이트골드160             110                 450         342
# 440        더치기계              20                 120        3232
# 441        마이더치             180                1010        1295
# 442      더치커피기계              60                 240        2467
# 443     더치커피추출기              10                  60       18255
#
#      total_search_count
# 0                  3160
# 1                   260
# 2                 10200
# 3                  3860
# 4                  4430
# ..                  ...
# 439                 560
# 440                 140
# 441                1190
# 442                 300
# 443                  70
#
# [444 rows x 5 columns]

# %% [markdown]
# #### 3. 개별과제 : 경쟁률
# - 아이템수/검색수 : 높을수록 경쟁이 심한 상품 키워드
# - 수집된 데이터에서 추가로 얻을수 있는 인사이트 추가
#     - 논리적인 인사이트이면 인사이트 수준에 대한 평가는 하지 않음

# %%
# 딥다라인, 실내자전거렌탈의 키워드가 경쟁령이 낮다.
result_df
# Out:
#    relKeyword  monthlyPcQcCnt  monthlyMobileQcCnt  item_count  \
# 0        딥다라인             370                3550          50
# 1     실내자전거렌탈             100                 790         581
# 2       실내자전거           18300              159100      245638
# 3       스핀바이크            2240               10400       22938
# 4      스피닝자전거            2380               25000       60342
# 5       스쿼트머신            2230               17100       45269
# 6       밸런스보드            5710               30200      105822
# 7       실내사이클            3600               32500      140261
# 8       온라인PT             580                1600       11983
# 9      하체운동기구            1070                7800       56684
# 10      실내싸이클            1290               11900      140261
# 11     다리운동기구             360                4110       73169
# 12      헬스자전거            1270               11500      243545
# 13     실내운동기구            1530               13300      341120
# 14    자전거운동기구             570                5550      158543
# 15         홈트            4500               19900      924110
# 16      홈트레이닝            3790                5660      612252
# 17       운동기구            4340               23600     2013909
# 18    가정용운동기구             420                2970      367701
# 19        라이딩             940                5720     1214412
#
#     total_search_count  competition_rate
# 0                 3920          0.012755
# 1                  890          0.652809
# 2               177400          1.384656
# 3                12640          1.814715
# 4                27380          2.203871
# 5                19330          2.341904
# 6                35910          2.946867
# 7                36100          3.885346
# 8                 2180          5.496789
# 9                 8870          6.390530
# 10               13190         10.633889
# 11                4470         16.368904
# 12               12770         19.071652
# 13               14830         23.002023
# 14                6120         25.905719
# 15               24400         37.873361
# 16                9450         64.788571
# 17               27940         72.079778
# 18                3390        108.466372
# 19                6660        182.344144

# %%
result_df['competition_rate'] = result_df['item_count']/result_df['total_search_count']
result_df.sort_values('competition_rate').head(50)
# Out:
#             relKeyword  monthlyPcQcCnt  monthlyMobileQcCnt  item_count  \
# 247             부산양도양수             100                 550           0
# 70   BULLETPROOFCOFFEE              10                  30           0
# 215            바른선달밤라떼              10                  10           0
# 400             남자체지방률            2130               18200          73
# 154            간헐적단식효과             330                2640          12
# 248              간헐적단식            8100               76100        1410
# 49              캐모마일효능            2650               25600         673
# 235            방탄커피만들기             260                3720         105
# 66              카모마일효능            1430               17200         673
# 361            간헐적단식커피             640                3410         154
# 218            방탄커피레시피              70                 590          29
# 24               커피박람회             800                2400         179
# 194             방탄커피효능              60                 410          28
# 76            더치커피만드는법              10                 390          37
# 355              김연아커피             320                2220         243
# 38                당뇨커피             460                4400         481
# 389          맥심모카골드400            2530                7450        1242
# 9                 방탄커피            5410               50300        8408
# 424             케톤식이요법              60                 250          58
# 5              캐모마일차효능             260                2320         634
# 142              커피대통령             220                1130         370
# 402          맥심모카골드사은품             180                 330         145
# 184                결명차             170                1010         337
# 216             방탄커피효과             250                4020        1276
# 321               연아커피             360                1700         668
# 291          맥심모카골드230              90                 460         180
# 18            키토제닉다이어트             420                3960        1453
# 86                루왁커피            1720               13100        4937
# 372           스타벅스더치커피              80                 780         287
# 3                   바륨             790                3070        1361
# 128               린저21             140                 910         371
# 421            옥수수수염효능              60                 300         129
# 42                커피맛집             270                7930        3162
# 176               돌체라떼            2840               24300       10613
# 63             남성피로회복제            1020                8670        3961
# 419               문블렌딩              70                 510         251
# 22               항산화커피             190                1920         948
# 135         루카스나인더블샷라떼             900                7190        3996
# 311             카누디카페인            2870               18100       10898
# 363         코스트코스타벅스원두             390                2880        1721
# 242           코스트코방탄커피              30                 430         246
# 198           방탄커피다이어트             180                2080        1271
# 82                코드브루              10                 100          64
# 364            카라멜마끼아또            1680               14000        9266
# 213           빅트레인토피모카             130                 950         650
# 73                콜드부르             140                 680         494
# 439         맥심화이트골드160             110                 450         342
# 422             홈카페레시피             210                1030         887
# 143             더치커피맛집              10                  50          43
# 102          맥심커피믹스400             660                2450        2244
#
#      total_search_count  competition_rate
# 247                 650          0.000000
# 70                   40          0.000000
# 215                  20          0.000000
# 400               20330          0.003591
# 154                2970          0.004040
# 248               84200          0.016746
# 49                28250          0.023823
# 235                3980          0.026382
# 66                18630          0.036125
# 361                4050          0.038025
# 218                 660          0.043939
# 24                 3200          0.055938
# 194                 470          0.059574
# 76                  400          0.092500
# 355                2540          0.095669
# 38                 4860          0.098971
# 389                9980          0.124449
# 9                 55710          0.150924
# 424                 310          0.187097
# 5                  2580          0.245736
# 142                1350          0.274074
# 402                 510          0.284314
# 184                1180          0.285593
# 216                4270          0.298829
# 321                2060          0.324272
# 291                 550          0.327273
# 18                 4380          0.331735
# 86                14820          0.333131
# 372                 860          0.333721
# 3                  3860          0.352591
# 128                1050          0.353333
# 421                 360          0.358333
# 42                 8200          0.385610
# 176               27140          0.391046
# 63                 9690          0.408772
# 419                 580          0.432759
# 22                 2110          0.449289
# 135                8090          0.493943
# 311               20970          0.519695
# 363                3270          0.526300
# 242                 460          0.534783
# 198                2260          0.562389
# 82                  110          0.581818
# 364               15680          0.590944
# 213                1080          0.601852
# 73                  820          0.602439
# 439                 560          0.610714
# 422                1240          0.715323
# 143                  60          0.716667
# 102                3110          0.721543

# %%
# 렉스파스핀엑스의 경쟁력이 낮기 때문에 해당 키워드로 진입하면 위험부담이 적다

# %% [markdown]
# #### 4. 조별과제 : 스마트 스토어를 운영한다고 생각하고 경쟁력이 낮으면서 많은 수익을 낼수 있는 키워드 찾기
# - 정답이 있는것은 아닙니다
# - 여러가지 가정과 데이터를 수집, 분석하여 판매할 상품과 키워드를 선정해 보시면 됩니다.
# - 앞서 2일간 했던 프로젝트와 같은 방법으로 수행하시면 됩니다.

# %% [markdown]
# ### 평가기준
#
# #### 개인평가(70)
#
#     - 기본 문제 해결(30)
#         - 데이터 수집 방법 : 10점
#             - 최적의 수집 방법을 사용했는지 확인
#         - 수집된 데이터의 결과 : 20점
#             - 1번: 키워드에 대한 검색량 데이터 수집 : 15점
#             - 2번: 검색어에 대한 상품등록수 수집 : 5점
#
#     - 적절한 주석 및 설명(10)
#         - 코드의 가독성 및 코드의 설명 : 10점
#
#     - 코드 오류(10)
#         - 발생 오류마다 : -2점
#
#     - 추가 분석(20)
#         - 인사이트 도출
#             - 경쟁률 데이터 출력 : 10점
#             - 추가 인사이트 : 10점
#
# #### 조별평가(30)
#
#     - 비지니스 인사이트 도출(5)
#         - 스마트 스토어 운영자 입장에서의 추가 인사이트 도출
#         - 예시) 선정한 상품으로 소호몰에서 1위 하였을경우 예상되는 매출
#         - 인사이트 도출을 위한 프로세스
#
#     - 실습문제의 분석(5)
#         - 제출 자료가 잘 정리되고 판매 상품과 키워드를 논리적으로 잘 선정
#         - 상품과 키워드 선정 자동화 > 가독성 좋은 키워드와 상품 선정 프로세스
#
#     - 실습문제의 적절한 정리(20)
#         - 프로젝트 주제(상품과 키워드 선정)에 맞는 논리적 인사이트가 있는지 확인
#         - 프로젝트 수행 후 추후 과제 및 느낀점
